# %%
score = float(input("Enter your Score: "))

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Enter your Score: 98
# Grade: A

# %%
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
def add(a,b):
  print(a+b)
add(10,20)
# Out:
# 30

# %%
def sub(a,b):
  return a-b   # return 10-20
print(sub(10,20))
# Out:
# -10

# %%
print("Neha")

print("Pole")
# Out:
# Neha
# Pole

# %%
# data Type
1.Numeric: Int, Float, Complex
2.Non Numeric : Str
3.Boolean
4.list
5. tuple
6. set
7. dictionary

# %%
# Int : 1,2,-1,-2..... infinity
print(5)
print(type(5))
# Out:
# 5
# <class 'int'>

# %%
#float: 0.0,0.1,0.2,........6.0,8.9.....infinity
print(0.0)
print(type(0.0))
# Out:
# 0.0
# <class 'float'>

# %%
#complex: Real+ Img part
#2+5j  #---- 2 is REal & 5 is Imaginary
print(2+5j)
print(type(2+5j))
# Out:
# (2+5j)
# <class 'complex'>

# %%
a=True
print(a)
# Out:
# True

# %%
print(type(a))
# Out:
# <class 'bool'>

# %%
a="python"

print(a)
print(type(a))
# Out:
# python
# <class 'str'>

# %%
print("python")
# Out:
# python

# %%
#

# %% [markdown]
# #how to install python
# - open cmd in your system
# - after opeining put the command  python --version.
# - if allready install then keep as it is, otherwise intall it manually.
#
# - go to the chrome and serach python download
# https://www.python.org/downloads/
#
# click on download.
# - go to the download folder and just click on download option

# %% [markdown]
# **Python History**
#
# - programming  Language
# - Guido Vann Rossum is the father of Python
# - Guido Start working in 1989 when he was devloping ABC Language.
# -python name came from guido's favorate TV show which was Monty's Python flying circus broadcasted BBC in 1969 to 1974.
# - it is Totally free for all, Anyone can contribute in it.
# -and the 1st realsed in 1991.
# - 2nd version is realsed in 2000.
# -3rd version is realsed in 2008.
# - currently we are using 3.14.2 version.
#
#
#
# # Feature of python
# - Python is open source
# - python is easy to learn
# - Python is platform independent.
# - python is interpreted as well as compiled
# - python is is High level programming language.
# - python is dynamically typed language.
# - python is procedural as well as object oriented programming langugae.
# - python is case sensitive.
# -we can do scripting
#
#
#
# # Flavour of python
# - c( cpython)
# - Java (jpython)
# - .Net(ironpython)

# %%
# if we want see to python keyword - for output purpose.
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
#  python syntax
#print() - for getting output
print("python")
# Out:
# python

# %%
print(25)
# Out:
# 25

# %%
#  python indetation
age=int(input("enter your age: "))
if age >18:
  print("you are eligible for vote")
else:
  print("you are not eligible for vote")
# Out:
# enter your age: 14
# you are not eligible for vote

# %%
# python Output
# text
print("hello guys!")   # with The Double Quotes

print('hello Guys!')   # With The Single Quote

Name="Neha"
print(Name)
# Out:
# hello guys!
# hello Guys!
# Neha

# %%
#Number
print(5)
# Out:
# 5

# %% [markdown]
# Comment in python
# - For the single Line  you can use # Symbol
# - For Paragraph Or multiple line you should go with the '''statement'''  or """ statement"""

# %%
'''python'''
# Out:
# 'python'

# %% [markdown]
# Variable in python
# - variable is nothing but the container which we use to staore the different data type.
# Ex:
# name="neha"
#
# # set of rule for variable
# - cannot start with number
# - _ (underscore) can you for variable name.
# - cannot use any built in keyword as variable name
# - Should be start A-Z or a-z with 0-9 digits.
# EX: Stud_Name, Student_1, stud1,_
#
# # - Camelcase : except the first ,start with a capital letter
# Ex:dataAnalysis="batch1"
#
# # pascal case: Each word start with capital
# Ex: DataAnalysis="batch1"
#
# # snake case:Each word separate with the underscore
# Ex: data_Analysis="batch1"

# %%
# Assigning Multiple values
x,y,z="Rahul", "Nikhil","Umer"
print(x)
# Out:
# Rahul

# %%
print(x,y,z)  # getting all together
# Out:
# Rahul Nikhil Umer

# %%
print(x+y+z)    #concatenation
# Out:
# RahulNikhilUmer

# %% [markdown]
# # Data Types
# - Numeric data type: Integer, Float, Complex
# - Non Numeric data type ( text) : string
# - Boolean : bool
# - data structure: list , tuple, set , dictionary

# %%
#Numeric data type: Integer, Float, Complex
# Integer: it goes -infinty to infinity & it is Natural Number It Does not allow Decimal Point.
Num = 10
print(Num)
print(type(Num))
# Out:
# 10
# <class 'int'>

# %%
# Flaot Data type
# it is Whole Number it contains Decimal Point
num=0.5
print(num)
print(type(num))
# Out:
# 0.5
# <class 'float'>

# %%
#complex: it is the combination Of Real & Imagimary Part
Num=5+2j
print(Num)
print(type(Num))
# Out:
# (5+2j)
# <class 'complex'>

# %%
a=4
print(a)
print(type(a))
b=complex(a)
print(b)
print(type(b))
# Out:
# 4
# <class 'int'>
# (4+0j)
# <class 'complex'>

# %%
a=4
print(a)
print(type(a))
b=str(a)
print(b)
print(type(b))
# Out:
# 4
# <class 'int'>
# 4
# <class 'str'>

# %%
#String : Textual Format
Name= "Rishi"
print(Name)
print(type(Name))
# Out:
# Rishi
# <class 'str'>

# %%
# Boolean : It is in Form of True Or False
A=False
print(A)
print(type(A))
res=float(A)
print(res)
print(type(res))
# Out:
# False
# <class 'bool'>
# 0.0
# <class 'float'>

# %%
# Type Casting: it is divided into the two types implicit,explicite
# Checking data type with the help of Existing Build in Keyword.
# explicute type casting
a=10
b=float(a)
print(a)
print(type(a))
print(b)
print(type(b))
c=complex(a)
print(c)
print(type(c))

print()
# Out:
# 10
# <class 'int'>
# 10.0
# <class 'float'>
# (10+0j)
# <class 'complex'>

# %%
# implicite typecsasting : doing Manually
a=10
print(a)
print(type(a))
print()

b=10+0.5
print(b)
print(type(b))
# Out:
# 10
# <class 'int'>
#
# 10.5
# <class 'float'>

# %%
#explicit : Existing keyword used
print(float(a))
print(type(float(a)))
# Out:
# 10.0
# <class 'float'>

# %% [markdown]
# # List Data Structure
#
# If we want to represent a group of individual objects as a single entity
# where insertion order preserved and duplicates are allowed, then we
# should go for List.
#
# - insertion order preserved.
# - duplicate objects are allowed.
# - heterogeneous objects are allowed.
# - List is dynamic because based on our requirement we can increase the size and decrease
# the size.
#
# # How to make a list:
# - In List the elements will be placed within square brackets and
# with comma seperator.[ ] apple , mango
# - We can differentiate duplicate elements by using index and we can preserve
# insertion order by using index.
# - Hence index will play very important role.
# - Python supports both positive and negative indexes.
# - +ve index means from left to right where as negative index means
# right to left.
#
#
# [10,"A","B",20, 30, 10]
# - List objects are mutable.i.e we can change the content.

# %%
##Creation of List Objects:
#1. We can create empty list object as follows...
lst=[]
print(lst)
print(type(lst))
# Out:
# []
# <class 'list'>

# %%
#2.With list() function:
lst=list(range[0,10,2])
print(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3588662563.py in <cell line: 0>()
#       1 #2.With list() function:
# ----> 2 lst=list(range[0,10,2])
#       3 print(lst)
#
# TypeError: type 'range' is not subscriptable
